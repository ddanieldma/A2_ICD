# %% [markdown]
# Escolher duas doenças no Brasil e plotar a distribuição dos casos entre as duas usando um plot do tipo hex bin
#
# por enquanto:
# - Alcohol Use Disorders x Cirrhosis and Other Chronic Liver Diseases

# %%
import pandas as pd

from bokeh.models import ColumnDataSource
from bokeh.plotting import output_notebook, show, figure
from bokeh.models import HoverTool

import os
os.chdir("C:/Users/B51995/Desktop/A2_ICD")

output_notebook()

df_cause_of_death = pd.read_csv("new_cause_of_death.csv")

df_alcohol_brasil = df_cause_of_death[df_cause_of_death["Country/Territory"] == "Brazil"].groupby("Year")[["Alcohol Use Disorders", "Cirrhosis and Other Chronic Liver Diseases"]].sum().reset_index()

display(df_alcohol_brasil)

data_alcohol_brasil = ColumnDataSource(df_alcohol_brasil)

plot = figure(match_aspect = True)

plot.title = "Distribuição de disordens de uso de alcool e doenças crônicas do fígado"
# plot.background_fill_color = "#440154"
plot.grid.visible = False

# r, bins = plot.hexbin(x = "Cirrhosis and Other Chronic Liver Diseases", y = "Alcohol Use Disorders", size = 0.5, hover_color = "pink", hover_alpha = 0.8, source = data_alcohol_brasil)

plot.circle(x = "Cirrhosis and Other Chronic Liver Diseases", y = "Alcohol Use Disorders", color = "Black", size = 1, source = data_alcohol_brasil)

# plot.add_tools(HoverTool(
#     tooltips = [("count", "@c")],
#     mode="mouse", point_policy="follow_mouse", renderers=[r]
# ))

show(plot)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a06a2076-2d02-4c16-bcfe-9f9628422054">Loading BokehJS ...</span>
#     </div>
#     Year  Alcohol Use Disorders  Cirrhosis and Other Chronic Liver Diseases
# 0   1990                   4593                                       24474
# 1   1991                   4749                                       24488
# 2   1992                   4920                                       24913
# 3   1993                   5131                                       25965
# 4   1994                   5329                                       26329
# 5   1995                   5518                                       26604
# ...

# %%
df_deaths_brazil = df_cause_of_death[df_cause_of_death["Country/Territory"] == "Brazil"]
data_deaths_brazil = ColumnDataSource(df_deaths_brazil)

plot = figure()
plot.scatter(x = "Year", y = "Cardiovascular Diseases", source = data_deaths_brazil)
plot.scatter(x = "Year", y = "Self-harm", source = data_deaths_brazil)
plot.scatter(x = "Year", y = "Tuberculosis", source = data_deaths_brazil)
plot.scatter(x = "Year", y = "Diarrheal Diseases", source = data_deaths_brazil)
plot.scatter(x = "Year", y = "Fire, Heat, and Hot Substances", source = data_deaths_brazil)

show(plot)
# Out:
#   <div id="b52f2a38-dcb0-4ce3-9f93-638cdf6bf2d1" data-root-id="p1139" style="display: contents;"></div>

# %% [markdown]
# Box plot
#
# Agrupar por país e fazer box plot

# %%
# display(df_cause_of_death[["Continente", "Cardiovascular Diseases"]].rename(columns = {"Continente" : "kind"}))
# display(df_cause_of_death.groupby("Country/Territory")[["Continente", "Cardiovascular Diseases"]].sum().rename(columns = {"Continente" : "kind"}))
df = df_cause_of_death.groupby("Country/Territory")[["Cardiovascular Diseases"]].sum().reset_index()
# display(df)

# organizando continentes
# fazendo lista com todos os países do dataset
lista_paises = list(df_cause_of_death["Country/Territory"].unique())
# criando uma subset com todos os países e seu respectivo continente
# Ao usarmos a função unique para que não haja repetição nos nomes dos continentes para cada país 
# (uma vez que temos os dados para cada país para cada um dos 30 anos), a coluna dos continentes
# armazena o valor para o continente dentro de um array de uma posição. Para colocarmos os valores 
# da coluna continente em uma lista, percorremos todos os valores da coluna e pegamos o valor na
# primeira posição (de um array de uma posição)
df_paises = df_cause_of_death.groupby("Country/Territory")["Continente"].unique().reset_index()
lista_continentes = []
for cada_continente in df_paises["Continente"]:
    lista_continentes.append(cada_continente[0])

print(lista_continentes)
print(len(lista_continentes))

# fazendo dicionário com as duas listas
dicionario_paises_continentes = dict(zip(lista_paises, lista_continentes))
print(dicionario_paises_continentes)

# adicionando continentes ao seus respectivos países no dataframe
# Out:
# ['Asia', 'Europe', 'Africa', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Europe', 'Oceania', 'Europe', 'Europe', 'North America', 'Asia', 'Asia', 'North America', 'Europe', 'Europe', 'North America', 'Africa', 'North America', 'Asia', 'South America', 'Europe', 'Africa', 'South America', 'Asia', 'Europe', 'Africa', 'Africa', 'Asia', 'Africa', 'North America', 'Africa', 'Africa', 'Africa', 'South America', 'Asia', 'South America', 'Africa', 'Africa', 'Oceania', 'North America', 'Africa', 'Europe', 'North America', 'Europe', 'Europe', 'Africa', 'Europe', 'Africa', 'North America', 'North America', 'South America', 'Africa', 'North America', 'Africa', 'Africa', 'Europe', 'Africa', 'Africa', 'Oceania', 'Europe', 'Europe', 'Africa', 'Africa', 'Europe', 'Europe', 'Africa', 'Europe', 'Europe', 'North America', 'Oceania', 'North America', 'Africa', 'Africa', 'South America', 'North America', 'North America', 'Europe', 'Europe', 'Asia', 'Asia', 'Asia', 'Asia', 'Europe', 
# ...

# %%
# Pegando total de mortes por acidentes cardiovasculares nos ultimos 30 anos para cada país mantendo coluna do continente
df_countries_cardio = df_cause_of_death.groupby(['Country/Territory', 'Continente']).agg({'Cardiovascular Diseases': 'sum'}).reset_index()
#separando pra 2019
df_countries_cardio_2019 = df_cause_of_death[df_cause_of_death["Year"] == 2019].groupby(['Country/Territory', 'Continente']).agg({'Cardiovascular Diseases': 'sum'}).reset_index()

display(df_countries_cardio)
display(df_countries_cardio_2019)
# Out:
#     Country/Territory     Continente  Cardiovascular Diseases
# 0         Afghanistan           Asia                  1607042
# 1             Albania         Europe                   270603
# 2             Algeria         Africa                  2123720
# 3      American Samoa        Oceania                     2851
# 4             Andorra         Europe                     3526
# ..                ...            ...                      ...
# 199         Venezuela  South America                  1158991
# 200           Vietnam           Asia                  5323920
# 201             Yemen           Asia                  1110837
# 202            Zambia         Africa                   360770
# 203          Zimbabwe         Africa                   408352
#
# [204 rows x 3 columns]
#     Country/Territory     Continente  Cardiovascular Diseases
# 0         Afghanistan           Asia                    61995
# 1             Albania         Europe                    12904
# ...

# %%
import pandas as pd

from bokeh.models import ColumnDataSource, Whisker, NumeralTickFormatter
from bokeh.plotting import figure, show, output_notebook
from bokeh.transform import factor_cmap

output_notebook()

# df_boxplot = df_countries_cardio_2019.rename(columns = {"Continente" : "kind"})
# # df = autompg2[["class", "hwy"]].rename(columns={"class": "kind"})

# kinds = df_boxplot.kind.unique()

# # calculando quartis por continente e colocando no dataframe o quartil
# # correspondente a cada continente
# qs = df_boxplot.groupby("kind")["Cardiovascular Diseases"].quantile([0.25, 0.5, 0.75])
# qs = qs.unstack().reset_index()
# qs.columns = ["kind", "q1", "q2", "q3"]
# df_boxplot = pd.merge(df_boxplot, qs, on="kind", how="left")

# # display(df_boxplot)

# # calculando distancia interquartil
# iqr = df_boxplot.q3 - df_boxplot.q1
# # setando limitantes superior e inferior
# df_boxplot["upper"] = df_boxplot.q3 + 1.5*iqr
# df_boxplot["lower"] = df_boxplot.q1 - 1.5*iqr

# df_agrupado = df_boxplot.groupby("kind").sum().reset_index()

# # display(df_agrupado)

# display(df_agrupado)
# source = ColumnDataSource(df_agrupado)

boxplot = figure(x_range=kinds, title="Distribuição de mortes por doenças cardiovasculares por continente", background_fill_color="#eaefef", y_axis_label="Mortes por acidentes cardiovasculares")
boxplot.sizing_mode = "stretch_width"
boxplot.min_width = 720
boxplot.height = 720

# outlier range
whisker = Whisker(base="kind", upper="upper", lower="lower", source=source)
whisker.upper_head.size = whisker.lower_head.size = 20
boxplot.add_layout(whisker)

# quantile boxes
cmap = factor_cmap("kind", "TolRainbow7", kinds)
# print(source)
boxplot.vbar("kind", 0.7, "q2", "q3", source=source, color=cmap, line_color="black")
boxplot.vbar("kind", 0.7, "q1", "q2", source=source, color=cmap, line_color="black")

# filtrando outliers selecionando todos os valores no dataframe que caem fora do range 
# estabelecido por df_boxplot.lower e df_boxplot.upper
outliers = df_agrupado[~df_agrupado["Cardiovascular Diseases"].between(df_agrupado.lower, df_agrupado.upper)]
# display(df_boxplot)
print(outliers)
boxplot.scatter("kind", "Cardiovascular Diseases", source=outliers, size=6, color="black", alpha=0.3)

boxplot.yaxis.formatter = NumeralTickFormatter(format = '0.0a')
boxplot.xgrid.grid_line_color = None
boxplot.axis.major_label_text_font_size="14px"
boxplot.axis.axis_label_text_font_size="12px"

show(boxplot)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="acb08867-cef1-4d48-8de5-26d3170aa8c9">Loading BokehJS ...</span>
#     </div>
#             kind                                  Country/Territory  \
# 0         Africa  AlgeriaAngolaBeninBotswanaBurkina FasoBurundiC...
# 1           Asia  AfghanistanBahrainBangladeshBhutanBruneiCambod...
# 2         Europe  AlbaniaAndorraArmeniaAustriaAzerbaijanBelarusB...
# 3  North America  Antigua and BarbudaBahamasBarbadosBelizeBermud...
# 4        Oceania  American SamoaAustraliaCook IslandsFijiGuamKir...
# 5  South America  ArgentinaBoliviaBrazilChileColombiaEcuadorGuya...
#
#    Cardiovascular Diseases        q1         q2         q3        upper  \
# ...
